# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
from scipy.optimize import curve_fit
from scipy.special import voigt_profile
import Intensity_Examiner as IE
import importlib

plt.rcParams["font.family"] = "Times New Roman"

importlib.reload(IE)
# Out:
# <module 'Intensity_Examiner' from 'C:\\Users\\User\\PycharmProjects\\Advanced-Lab-Code\\Intensity_Runs_120K\\Intensity_Examiner.py'>

# %%
file = "120K_Section_A.xlsx"
sheets = ["9795"]
cols = [["PS_0", "PS_1", "PS_2", "PS_3", "PS_4"]]
start_index = [9795]

# %%
popt, cov, rchi2 = IE.analyse_ruby_spectrum(
    file=file,
    sheet_name=sheets[0],
    columns=cols[0],
    start_index=start_index,
    mask_fraction = 0.05
)
# Out:
# ----- Fit Parameters -----
# R1: 695.373 ± 1014195.589 nm
# Theoretical R1: 694.3 nm
# Amplitude frac R1: 0.0073
#
# R2: 693.382 ± 0.006 nm
# Theoretical R2: 692.9 nm
# Amplitude frac R2: 0.9927
#
# Reduced Chi²: 0.953

# %%
print(popt)
# Out:
# [ 1.11152833e-04  6.93382473e+02  5.10662533e-01  2.87093817e-01
#   8.11951401e-07  1.99038852e+00  8.22028021e+01 -5.73373755e-06]
