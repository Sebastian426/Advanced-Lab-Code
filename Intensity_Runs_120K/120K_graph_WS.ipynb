# %%
import Wide_Spectra_Pipeline as WSP
import importlib

importlib.reload(WSP)
# Out:
# <module 'Wide_Spectra_Pipeline' from 'C:\\Users\\sebas\\PycharmProjects\\Advanced-Lab-Code\\Intensity_Runs_120K\\Wide_Spectra_Pipeline.py'>

# %%
#input parameters

file = "120K_Section_A.xlsx"
sheets = "9830"
cols = ["WS_0", "WS_1", "WS_2", "WS_3"]
start_index = 9830
padding = [164, 225]

# %%
pop, cov = WSP.run_pipeline(file, sheets, cols, start_index, padding)
# Out:
# ------ Summary Statistics ------
# Reduced Chi Squared: 1.3543
# ----- R1 -----
# R1 Theoretical: 694.3
# R1 Observed: 693.4558 ± 0.11708449246313547
# ----- R2 -----
# R2 Theoretical: 692.9
# R2 Observed: 691.9070 ± 0.16945601167022128
