# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
from scipy.optimize import curve_fit

import Calibration_Function_V2 as CF2

# %%
# Data Processing
wavelengths = [632.8,  #Red
               594.1,  #Orange
               543.5,  #Green
               ]

start_indexes = [6980,  #Red
                 6935,  #Orange
                 6890,  #Green
                 ]

sheets = ['Red',
          'Orange',
          'Green'
          ]

cols = [
    ['R_A_0', 'R_A_1', 'R_A_2', 'R_A_3', 'R_A_4', 'R_A_5', 'R_A_6', 'R_A_7', 'R_A_8', 'R_A_9'],  #Red
    ['O_A_0', 'O_A_1', 'O_A_2', 'O_A_3', 'O_A_4', 'O_A_5', 'O_A_6', 'O_A_7', 'O_A_8', 'O_A_9'],  # Orange
    ['G_A_0', 'G_A_1', 'G_A_2', 'G_A_3', 'G_A_4']  #Green
]
file = "Calibration_Runs.xlsx"

# %%
results = CF2.peak_extractor(
    file = file,
    sheets = sheets,
    cols = cols,
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 results = CF2.peak_extractor(
#       2     file = file,
#       3     sheets = sheets,
#       4     cols = cols,
#       5 )
#
# File ~\PycharmProjects\Advanced-Lab-Code\Monochromator_Calibration\Calibration_Function_V2.py:52, in peak_extractor(file, sheets, cols)
#      44 p0 = [
#      45     mean_amp.max(),                 # A
#      46     np.argmax(mean_amp),            # x0
#      47     10,                              # B (width)
#      48     mean_amp.min()                  # C
#      49 ]
#      51 # ---- Fit ----
# ---> 52 popt, cov = curve_fit(
#      53     Lorentzian_Function,
#      54     xdata=index_list,
#      55     ydata=mean_amp,
#      56     sigma=std_amp,
#      57     absolute_sigma=True,
#      58     p0=p0
#      59 )
#      61 # ---- Statistics ----
#      62 dof = len(mean_amp) - len(popt)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\scipy\optimize\_minpack_py.py:1021, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, nan_policy, **kwargs)
#    1018 if ydata.size != 1 and n > ydata.size:
#    1019     raise TypeError(f"The number of func parameters={n} must not"
#    1020                     f" exceed the number of data points={ydata.size}")
# -> 1021 res = leastsq(func, p0, Dfun=jac, full_output=1, **kwargs)
#    1022 popt, pcov, infodict, errmsg, ier = res
#    1023 ysize = len(infodict['fvec'])
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\scipy\optimize\_minpack_py.py:426, in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     424 if not isinstance(args, tuple):
#     425     args = (args,)
# --> 426 shape, dtype = _check_func('leastsq', 'func', func, x0, args, n)
#     427 m = shape[0]
#     429 if n > m:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\scipy\optimize\_minpack_py.py:24, in _check_func(checker, argname, thefunc, x0, args, numinputs, output_shape)
#      22 def _check_func(checker, argname, thefunc, x0, args, numinputs,
#      23                 output_shape=None):
# ---> 24     res = atleast_1d(thefunc(*((x0[:numinputs],) + args)))
#      25     if (output_shape is not None) and (shape(res) != output_shape):
#      26         if (output_shape[0] != 1):
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\scipy\optimize\_minpack_py.py:523, in _lightweight_memoizer.<locals>._memoized_func(params)
#     520 elif _memoized_func.last_params is not None:
#     521     _memoized_func.skip_lookup = True
# --> 523 val = f(params)
#     525 if _memoized_func.last_params is None:
#     526     _memoized_func.last_params = np.copy(params)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\scipy\optimize\_minpack_py.py:543, in _wrap_func.<locals>.func_wrapped(params)
#     542 def func_wrapped(params):
# --> 543     return transform * (func(xdata, *params) - ydata)
#
# TypeError: Lorentzian_Function() takes 4 positional arguments but 5 were given
