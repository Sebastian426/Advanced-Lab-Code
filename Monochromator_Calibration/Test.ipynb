# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
from scipy.optimize import curve_fit

import Calibration_Function_V2 as CF2

# %%
# Data Processing
wavelengths = [632.8,  #Red
               594.1,  #Orange
               543.5,  #Green
               ]

start_indexes = [6980,  #Red
                 6935,  #Orange
                 6890,  #Green
                 ]

sheets = ['Red',
          'Orange',
          'Green'
          ]

cols = [
    ['R_A_0', 'R_A_1', 'R_A_2', 'R_A_3', 'R_A_4', 'R_A_5', 'R_A_6', 'R_A_7', 'R_A_8', 'R_A_9'],  #Red
    ['O_A_0', 'O_A_1', 'O_A_2', 'O_A_3', 'O_A_4', 'O_A_5', 'O_A_6', 'O_A_7', 'O_A_8', 'O_A_9'],  # Orange
    ['G_A_0', 'G_A_1', 'G_A_2', 'G_A_3', 'G_A_4']  #Green
]
file = "Calibration_Runs.xlsx"

# %%
results = CF2.peak_extractor(
    file = file,
    sheets = sheets,
    cols = cols,
)
# Out:
#  ---- Results ----
# Sheet: Red
# Peak index = 29.230 ± 0.333
# Reduced χ² = 0.963
# ----- ----- -----
# C:\Users\sebas\AppData\Local\Programs\Python\Python314\Lib\site-packages\scipy\optimize\_minpack_py.py:989: RuntimeWarning: divide by zero encountered in divide
#   transform = 1.0 / sigma
# C:\Users\sebas\PycharmProjects\Advanced-Lab-Code\Monochromator_Calibration\Calibration_Function_V2.py:50: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, cov = curve_fit(
# C:\Users\sebas\PycharmProjects\Advanced-Lab-Code\Monochromator_Calibration\Calibration_Function_V2.py:13: RuntimeWarning: divide by zero encountered in divide
#   return(np.sum(((y_data - model(x_data, *model_params))/y_error)**2))
#  ---- Results ----
# Sheet: Orange
# Peak index = 21.000 ± inf
# Reduced χ² = inf
# ----- ----- -----
#  ---- Results ----
# Sheet: Green
# Peak index = 61.988 ± 1.193
# Reduced χ² = 0.041
# ----- ----- -----
