# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
from scipy.optimize import curve_fit

import importlib

import Calibration_Function_V2 as CF2

importlib.reload(CF2)
# Out:
# <module 'Calibration_Function_V2' from 'C:\\Users\\sebas\\PycharmProjects\\Advanced-Lab-Code\\Monochromator_Calibration\\Calibration_Function_V2.py'>

# %%
# Data Processing
wavelengths = [632.8,  #Red
               594.1,  #Orange
               543.5,  #Green
               ]

start_indexes = [6980,  #Red
                 6935,  #Orange
                 6890,  #Green
                 ]

sheets = ['Red',
          'Orange',
          'Green'
          ]

cols = [
    ['R_A_0', 'R_A_1', 'R_A_2', 'R_A_3', 'R_A_4', 'R_A_5', 'R_A_6', 'R_A_7', 'R_A_8', 'R_A_9'],  #Red
    ['O_A_0', 'O_A_1', 'O_A_2', 'O_A_3', 'O_A_4', 'O_A_5', 'O_A_6', 'O_A_7', 'O_A_8', 'O_A_9'],  # Orange
    ['G_A_0', 'G_A_1', 'G_A_2', 'G_A_3', 'G_A_4']  #Green
]
file = "Calibration_Runs.xlsx"

# %%
results = CF2.peak_extractor(
    file = file,
    sheets = sheets,
    cols = cols,
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 results = CF2.peak_extractor(
#       2     file = file,
#       3     sheets = sheets,
#       4     cols = cols,
#       5 )
#
# File ~\PycharmProjects\Advanced-Lab-Code\Monochromator_Calibration\Calibration_Function_V2.py:116, in peak_extractor(file, sheets, cols, amplitude_frac, uncertainty_frac, min_points, min_width, max_width)
#     114 # ---- Statistics ----
#     115 dof = len(x_fitdata) - len(popt)
# --> 116 chi2 = chi_squared(
#     117     Lorentzian_Function,
#     118     popt,
#     119     x_fitdata,
#     120     y_fitdata,
#     121     err_fitdata
#     122 )
#     123 rchi2 = reduced_chi_squared(chi2, dof)
#     125 peak = popt[1]
#
# File ~\PycharmProjects\Advanced-Lab-Code\Monochromator_Calibration\Calibration_Function_V2.py:13, in chi_squared(model_params, model, x_data, y_data, y_error)
#      12 def chi_squared(model_params, model, x_data, y_data, y_error):
# ---> 13     return(np.sum(((y_data - model(x_data, *model_params))/y_error)**2))
#
# TypeError: Value after * must be an iterable, not function
