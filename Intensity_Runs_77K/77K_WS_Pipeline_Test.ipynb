# %%
import Wide_Spectra_Pipeline as WSP
import importlib

importlib.reload(WSP)
# Out:
# <module 'Wide_Spectra_Pipeline' from 'C:\\Users\\User\\PycharmProjects\\Advanced-Lab-Code\\Intensity_Runs_77K\\Wide_Spectra_Pipeline.py'>

# %%
#input parameters

file = "77K_Section_A.xlsx"
sheets = "9830"
cols = ["WS_0","WS_1","WS_2","WS_3","WS_4","WS_5","WS_6","WS_7"]
start_index = 9830
padding = [164,225]

# %%
pop, cov = WSP.run_pipeline(file,sheets,cols,start_index,padding)
# Out:
# ------ Summary Statistics ------
# Reduced Chi Squared: 1.5502
# ----- R1 -----
# R1 Theoretical: 694.3
# R1 Observed: 693.7584 ± 0.059314896518325874
# ----- R2 -----
# R2 Theoretical: 692.9
# R2 Observed: 692.1374 ± 0.07425740588268065
